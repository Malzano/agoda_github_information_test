# %%
import requests
import json
#the required first parameter of the 'get' method is the 'url':
def getPulls(path: str):
  endpoint =  'https://immense-retreat-96686.herokuapp.com/pulls/' + path
  info = requests.get(endpoint)
  info = info.json()
  print('Repository' + path + "top 10 issues are : ")
  x = 0
  for i in range(len(info)):
    print('#'+ str(info[i]['number']) + '-' + info[i]['title'] )
    print('Created by ' + info[i]['user']['login'] + " at " + info[i]["created_at"])
    print("PR is" + info[i]['state'] +'\n')
    if x > 9:
      break
def getIssues(path: str):
  endpoint =  'https://immense-retreat-96686.herokuapp.com/issues/' + path
  info = requests.get(endpoint)
  info = info.json()
  print('Repository' + path + "top 10 issues are :")
  x = 0
  for i in range(len(info)):
    print('#'+ str(info[i]['number']) + '-' + info[i]['title'])
    print('Created by ' + info[i]['user']['login'] + " at " + info[i]["created_at"])
    print("Issue is" + info[i]['state'] +'\n')
    if x > 9:
      break
#print the response text (the content of the requested file):
while True:
  path = input("Enter the repository name (format: owner/repository) : ")
  if len(path.split('/')) != 2:
    print("please enter the correct format, try again") 
    continue
  req_type = input("Enter the information type (pull-requests, issues : ")
  if req_type not in ('pull-requests', 'issues'):
    print("please enter the correct format, try again") 
    continue
  if req_type == 'pull-requests':
    data = getPulls(path)
    getPulls(path)
  else:
    data = getPulls(path)
    getIssues(path)
# Out:
# Enter the repository name (format: owner/repository) : atom/atom
# Enter the information type (pull-requests, issues : pull-requests
# Repositoryatom/atomtop 10 issues are :
# #22069-⬆️ postcss@8.2.8
# Created by atom-build at 2021-03-22T03:18:48Z
# Issue isopen
#
# #22068-⬆️ normalize-package-data@3.0.2
# Created by atom-build at 2021-03-22T03:18:45Z
# Issue isopen
#
# #22067-⬆️ mocha@8.3.2
# Created by atom-build at 2021-03-22T03:18:41Z
# Issue isopen
#
# #22066-⬆️ marked@2.0.1
# Created by atom-build at 2021-03-22T03:18:37Z
# Issue isopen
#
# #22065-⬆️ less-cache@1.1.1
# Created by atom-build at 2021-03-22T03:18:34Z
# Issue isopen
#
# #22064-⬆️ jasmine-reporters@2.4.0
# Created by atom-build at 2021-03-22T03:18:30Z
# Issue isopen
#
# #22063-⬆️ git-utils@5.7.1
# Created by atom-build at 2021-03-22T03:18:26Z
# Issue isopen
#
# #22062-⬆️ fs-admin@0.16.0
# Created by atom-build at 2021-03-22T03:18:22Z
# Issue isopen
#
# #22061-⬆️ focus-trap@6.3.0
# Created by atom-build at 2021-03-22T03:18:18Z
# Issue isopen
#
# #22060-⬆️ chai@4.3.4
# Created by atom-build at 2021-03-22T03:18:14Z
# Issue isopen
#
# #22059-⬆️ babel-core@6.26.3
# Created by atom-build at 2021-03-22T03:18:11Z
# Issue isopen
#
# #22058-⬆️ atom-select-list@0.8.0
# Created by atom-build at 2021-03-22T03:18:07Z
# Issue isopen
#
# #22057-Update package.json
# Created by zachrytwood at 2021-03-22T01:51:32Z
# Issue isopen
#
# #22055-utils.less: Update comment to reflect final PR wording
# Created by DeeDeeG at 2021-03-21T22:37:22Z
# Issue isopen
#
# #22053-Fix: remove unused parser instance
# Created by romgrk at 2021-03-21T04:44:03Z
# Issue isopen
#
# #22050-Fix context menu right click not working ( alternative fix )
# Created by asturur at 2021-03-19T10:58:30Z
# Issue isopen
#
# #22034-Added Github Discussions for discussions
# Created by ThatXliner at 2021-03-15T17:52:40Z
# Issue isopen
#
# #22032-Fix typo in menu-sort-helpers-spec.js
# Created by eltociear at 2021-03-14T08:40:08Z
# Issue isopen
#
# #22015-Update required dependencies for Debian/Ubuntu
# Created by mfonville at 2021-03-08T22:53:31Z
# Issue isopen
#
# #22011-Don't merge, just a test: Electron to 11.3.0
# Created by mfonville at 2021-03-07T14:44:54Z
# Issue isopen
#
# #21963-⬆️ Bump language-css to 0.44.5
# Created by DeeDeeG at 2021-02-14T21:20:01Z
# Issue isopen
#
# #21939-⬆️ Bump marked from 1.2.0 to 2.0.0
# Created by dependabot[bot] at 2021-02-08T21:27:36Z
# Issue isopen
#
# #21916-Bump minidump @aminya/minidump@0.19.0-10
# Created by aminya at 2021-02-01T21:52:12Z
# Issue isopen
#
# #21631-git-diff: Fix subfolder git detection
# Created by utkarshgupta137 at 2020-11-01T20:03:01Z
# Issue isopen
#
# #21623-Babel 7 - Take 2
# Created by aminya at 2020-10-31T13:26:48Z
# Issue isopen
#
# #21431-Parallel Clean
# Created by aminya at 2020-10-02T20:32:06Z
# Issue isopen
#
# #21421-Parallel copy-assets
# Created by aminya at 2020-10-01T11:41:05Z
# Issue isopen
#
# #21401-Parallel transpiling (build)
# Created by aminya at 2020-09-28T06:40:09Z
# Issue isopen
#
# #21393-Appendable scopes in Tree-sitter grammars
# Created by chbk at 2020-09-27T06:40:37Z
# Issue isopen
#
# #21379-Use the Visual Studio 2017 instead of windows-build-tools v4
# Created by aminya at 2020-09-24T08:57:55Z
# Issue isopen
#
# Repositoryatom/atomtop 10 issues are :
# #22069-⬆️ postcss@8.2.8
# Created by atom-build at 2021-03-22T03:18:48Z
# Issue isopen
#
# #22068-⬆️ normalize-package-data@3.0.2
# Created by atom-build at 2021-03-22T03:18:45Z
# Issue isopen
#
# #22067-⬆️ mocha@8.3.2
# Created by atom-build at 2021-03-22T03:18:41Z
# Issue isopen
#
# #22066-⬆️ marked@2.0.1
# Created by atom-build at 2021-03-22T03:18:37Z
# Issue isopen
#
# #22065-⬆️ less-cache@1.1.1
# Created by atom-build at 2021-03-22T03:18:34Z
# Issue isopen
#
# #22064-⬆️ jasmine-reporters@2.4.0
# Created by atom-build at 2021-03-22T03:18:30Z
# Issue isopen
#
# #22063-⬆️ git-utils@5.7.1
# Created by atom-build at 2021-03-22T03:18:26Z
# Issue isopen
#
# #22062-⬆️ fs-admin@0.16.0
# Created by atom-build at 2021-03-22T03:18:22Z
# Issue isopen
#
# #22061-⬆️ focus-trap@6.3.0
# Created by atom-build at 2021-03-22T03:18:18Z
# Issue isopen
#
# #22060-⬆️ chai@4.3.4
# Created by atom-build at 2021-03-22T03:18:14Z
# Issue isopen
#
# #22059-⬆️ babel-core@6.26.3
# Created by atom-build at 2021-03-22T03:18:11Z
# Issue isopen
#
# #22058-⬆️ atom-select-list@0.8.0
# Created by atom-build at 2021-03-22T03:18:07Z
# Issue isopen
#
# #22057-Update package.json
# Created by zachrytwood at 2021-03-22T01:51:32Z
# Issue isopen
#
# #22055-utils.less: Update comment to reflect final PR wording
# Created by DeeDeeG at 2021-03-21T22:37:22Z
# Issue isopen
#
# #22053-Fix: remove unused parser instance
# Created by romgrk at 2021-03-21T04:44:03Z
# Issue isopen
#
# #22050-Fix context menu right click not working ( alternative fix )
# Created by asturur at 2021-03-19T10:58:30Z
# Issue isopen
#
# #22034-Added Github Discussions for discussions
# Created by ThatXliner at 2021-03-15T17:52:40Z
# Issue isopen
#
# #22032-Fix typo in menu-sort-helpers-spec.js
# Created by eltociear at 2021-03-14T08:40:08Z
# Issue isopen
#
# #22015-Update required dependencies for Debian/Ubuntu
# Created by mfonville at 2021-03-08T22:53:31Z
# Issue isopen
#
# #22011-Don't merge, just a test: Electron to 11.3.0
# Created by mfonville at 2021-03-07T14:44:54Z
# Issue isopen
#
# #21963-⬆️ Bump language-css to 0.44.5
# Created by DeeDeeG at 2021-02-14T21:20:01Z
# Issue isopen
#
# #21939-⬆️ Bump marked from 1.2.0 to 2.0.0
# Created by dependabot[bot] at 2021-02-08T21:27:36Z
# Issue isopen
#
# #21916-Bump minidump @aminya/minidump@0.19.0-10
# Created by aminya at 2021-02-01T21:52:12Z
# Issue isopen
#
# #21631-git-diff: Fix subfolder git detection
# Created by utkarshgupta137 at 2020-11-01T20:03:01Z
# Issue isopen
#
# #21623-Babel 7 - Take 2
# Created by aminya at 2020-10-31T13:26:48Z
# Issue isopen
#
# #21431-Parallel Clean
# Created by aminya at 2020-10-02T20:32:06Z
# Issue isopen
#
# #21421-Parallel copy-assets
# Created by aminya at 2020-10-01T11:41:05Z
# Issue isopen
#
# #21401-Parallel transpiling (build)
# Created by aminya at 2020-09-28T06:40:09Z
# Issue isopen
#
# #21393-Appendable scopes in Tree-sitter grammars
# Created by chbk at 2020-09-27T06:40:37Z
# Issue isopen
#
# #21379-Use the Visual Studio 2017 instead of windows-build-tools v4
# Created by aminya at 2020-09-24T08:57:55Z
# Issue isopen
